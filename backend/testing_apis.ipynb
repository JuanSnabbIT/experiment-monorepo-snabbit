# %%
import requests

# %%
anio = 2024  # Change this to the year you want to test
url = f'https://apis.digital.gob.cl/fl/feriados/{anio}'

try:
    response = requests.get(url)
    response.raise_for_status()  # Check for HTTP errors
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except requests.exceptions.RequestException as req_err:
    print(f"Request error occurred: {req_err}")
else:
    try:
        feriados = response.json()
        if feriados:
            print(f"Feriados for the year {anio}:")
            for feriado in feriados:
                nombre = feriado.get('nombre', 'N/A')
                fecha = feriado.get('fecha', 'N/A')
                irrenunciable = feriado.get('irrenunciable', 'N/A')
                tipo = feriado.get('tipo', 'N/A')
                print(f"- Fecha: {fecha}, Nombre: {nombre}, Irrenunciable: {irrenunciable}, Tipo: {tipo}")
        else:
            print(f"No holidays found for the year {anio}.")
    except ValueError as json_err:
        print(f"JSON decode error: {json_err}")
# Out:
# Request error occurred: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
years_to_test = [2022, 2023, 2024, 2025]

for anio in years_to_test:
    url = f'https://apis.digital.gob.cl/fl/feriados/{anio}'
    print(f"\nTesting for year {anio}:")
    try:
        response = requests.get(url)
        response.raise_for_status()
    except requests.exceptions.HTTPError as http_err:
        print(f"- HTTP error occurred: {http_err}")
        continue
    except requests.exceptions.RequestException as req_err:
        print(f"- Request error occurred: {req_err}")
        continue
    else:
        try:
            feriados = response.json()
            if feriados:
                print(f"- Found {len(feriados)} holidays for the year {anio}.")
            else:
                print(f"- No holidays found for the year {anio}.")
        except ValueError as json_err:
            print(f"- JSON decode error: {json_err}")
# Out:
# Testing for year 2022:
# - Request error occurred: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Testing for year 2023:
# - Request error occurred: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Testing for year 2024:
# - Request error occurred: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Testing for year 2025:
# - Request error occurred: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
